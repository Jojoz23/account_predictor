# %% [markdown]
# # Account Predictor - Data Collection and Exploration
#
# This notebook is for collecting and exploring your bookkeeping transaction data.
#
# ## Data Structure Expected
# The model expects transaction data with the following columns:
# - **Date**: Transaction date
# - **Description**: Transaction description/text
# - **Account**: Account category (this is what we want to predict)
# - **Amount**: Transaction amount (positive for income, negative for expenses)
#
# ## Steps
# 1. Load your existing bookkeeping data
# 2. Explore the data structure and quality
# 3. Clean and preprocess the data
# 4. Analyze patterns in account assignments

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Set up plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## 1. Load Your Data
#
# Replace the file path below with the path to your bookkeeping data file (CSV, Excel, etc.)

# %%
# TODO: Replace with your actual data file path
# Example: data_file = '../data/transactions.csv'
data_file = '../data/your_transactions.csv'

# Uncomment and modify based on your file format:
# df = pd.read_csv(data_file)
# df = pd.read_excel(data_file)

# For now, let's create a sample dataset to demonstrate the structure
# Note: Your format is Date, Description, Account, Amount
sample_data = {
    'Date': ['2024-01-15', '2024-01-16', '2024-01-17', '2024-01-18', '2024-01-19'],
    'Description': [
        'Office Supplies - Staples',
        'Client Payment - ABC Corp',
        'Electricity Bill - ConEd',
        'Software Subscription - Adobe',
        'Business Lunch - Restaurant'
    ],
    'Account': ['Office Expenses', 'Revenue', 'Utilities', 'Software', 'Meals & Entertainment'],
    'Amount': [-45.50, 2500.00, -120.75, -29.99, -85.00]
}

df = pd.DataFrame(sample_data)
print("Sample data structure (your format: Date, Description, Account, Amount):")
print(df.head())
print(f"\nData shape: {df.shape}")
# Out:
# Sample data structure (your format: Date, Description, Account, Amount):
#          Date                    Description                Account   Amount
# 0  2024-01-15      Office Supplies - Staples        Office Expenses   -45.50
# 1  2024-01-16      Client Payment - ABC Corp                Revenue  2500.00
# 2  2024-01-17       Electricity Bill - ConEd              Utilities  -120.75
# 3  2024-01-18  Software Subscription - Adobe               Software   -29.99
# 4  2024-01-19    Business Lunch - Restaurant  Meals & Entertainment   -85.00
#
# Data shape: (5, 4)
